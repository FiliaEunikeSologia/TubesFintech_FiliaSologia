# %% [markdown]
# <a href="https://colab.research.google.com/github/FiliaEunikeSologia/TubesFintech_FiliaSologia/blob/main/tubes_fintech_filia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tugas Besar Individu Mata Kuliah Analisis Keputusan Teknologi Finansial**

# %% [markdown]
# # 1. PENDAHULUAN

# %% [markdown]
# Tugas ini merupakan tugas akhir untuk memenuhi penilaian akhir MK Analisa Keputusan untuk Teknologi Finansial.
# Adapun dataset terpilih adalah Credit Scoring sesuai URL berikut https://github.com/gastonstat/CreditScoring/blob/master/CleanCreditScoring.csv
#
# Model Machine Learning yang digunakan adalah....
#
# Pada bagian di bawah ini saya tampilkan dataset yang digunakan

# %% [markdown]
# # 2. DATA LOADING

# %% [markdown]
# Adapun proses Data Loading dari dataset yang digunakan menggunakan kode yang dieksekusi sebagai berikut

# %%
#IMPORT LIBRARIES DAN SETUP
# Mount Google Drive (untuk pengambilan dataset yg disimpan di drive)
from google.colab import drive
drive.mount('/content/drive')

# Import libraries dasar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Import libraries untuk machine learning
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (classification_report, confusion_matrix,
                             accuracy_score, precision_score, recall_score,
                             f1_score, roc_auc_score, roc_curve)
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
import joblib

# Konfigurasi visualisasi
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Hasil dari eksekusi kode di atas adalah sebagai berikut :

# %%
print("✓ Semua libraries berhasil diimport")
# Out:
# ✓ Semua libraries berhasil diimport

# %%
import pandas as pd

#LOAD DATASET
file_path_raw = '/content/drive/MyDrive/TUBES-FINTECH/Credit/CreditScoring.csv'
file_path_clean = '/content/drive/MyDrive/TUBES-FINTECH/Credit/CleanCreditScoring (1).csv'

df_raw = pd.read_csv(file_path_raw)
df_clean = pd.read_csv(file_path_clean)
print("="*60)
print("INFORMASI DATASET")
print("="*60)
print(f"\nRAW Dataset Shape: {df_raw.shape}")
print(f"CLEAN Dataset Shape: {df_clean.shape}")
print(f"\nMenggunakan CLEAN dataset untuk analisis")
# Out:
# ...
# INFORMASI DATASET
# ...
#
# RAW Dataset Shape: (4455, 14)
# CLEAN Dataset Shape: (4446, 27)
#
# Menggunakan CLEAN dataset untuk analisis

# %%
### 2.3 Initial Data Exploration
# Display informasi dasar dataset
print("\n" + "="*60)
print("STRUKTUR DATA")
print("="*60)
print("\nNama Kolom dan Tipe Data:")
print(df_clean.dtypes)

print("\n" + "="*60)
print("PREVIEW DATA (5 Baris Pertama)")
print("="*60)
print(df_clean.head())

print("\n" + "="*60)
print("STATISTIK DESKRIPTIF")
print("="*60)
print(df_clean.describe())

# Check missing values
print("\n" + "="*60)
print("MISSING VALUES")
print("="*60)
missing = df_clean.isnull().sum()
print(f"Total missing values: {missing.sum()}")
if missing.sum() > 0:
    print("\nDetail missing values per kolom:")
    print(missing[missing > 0])
else:
    print("✓ Tidak ada missing values")

# Check data shape
print("\n" + "="*60)
print("DIMENSI DATA")
print("="*60)
print(f"Jumlah Baris (Records): {df_clean.shape[0]:,}")
print(f"Jumlah Kolom (Features): {df_clean.shape[1]}")
# Out:
# ...
# STRUKTUR DATA
# ...
#
# Nama Kolom dan Tipe Data:
# Status         object
# Seniority       int64
# Home           object
# Time            int64
# Age             int64
# Marital        object
# Records        object
# Job            object
# Expenses        int64
# Income          int64
# Assets          int64
# Debt            int64
# Amount          int64
# Price           int64
# Finrat        float64
# Savings       float64
# seniorityR     object
# timeR          object
# ageR           object
# expensesR      object
# incomeR        object
# assetsR        object
# debtR          object
# amountR        object
# priceR         object
# finratR        object
# savingsR       object
# dtype: object
#
# ...
# PREVIEW DATA (5 Baris Pertama)
# ...
#   Status  Seniority   Home  Time  Age  Marital  Records        Job  Expenses  \
# 0   good          9   rent    60   30  married   no_rec  freelance        73
# 1   good         17   rent    60   58    widow   no_rec      fixed        48
# ...

# %% [markdown]
# # 3. STATISTICAL SUMMARY OF THE DATASET

# %% [markdown]
# # 4. DATASET PREPARATION

# %% [markdown]
# # 5. MODELLING AND EVALUATION

# %% [markdown]
# # 6. DATA VISUALIZATION

# %% [markdown]
# # 7. MODEL DEPLOYMENT AND TEST
